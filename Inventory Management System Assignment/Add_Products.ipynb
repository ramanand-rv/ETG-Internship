# %%
import json

fd = open("record.json",'r')
r = fd.read()
fd.close()

record = json.loads(r)

# %%
record
# Out:
# {'1001': {'comp': 'fasai',
#   'name': 'Choco Cake',
#   'no': 12348,
#   'pr': 100,
#   'qn': 34},
#  '1002': {'comp': 'Amul',
#   'name': 'Milk Cake',
#   'no': 12348,
#   'pr': 800,
#   'qn': 100},
#  '1003': {'comp': 'cocacola',
#   'name': 'Drink',
#   'no': 12348,
#   'pr': 85,
#   'qn': 100},
#  '1004': {'comp': 'Amul', 'name': 'Candy', 'no': 12348, 'pr': 5, 'qn': 1000},
#  '1005': {'comp': 'cello', 'name': 'Pen', 'no': 12348, 'pr': 20, 'qn': 100},
#  '1006': {'comp': 'iphone',
#   'name': 'Phone',
#   'no': 12348,
#   'pr': 50000,
#   'qn': 10},
#  '1007': {'comp': 'Sony', 'name': 'Mic', 'no': 12348, 'pr': 1500, 'qn': 0},
#  '1008': {'comp': 'Sony India Pt Ltd',
#   'name': 'Case',
#   'no': 12348,
#   'pr': 599,
#   'qn': 5},
#  '1009': {'comp': 'Sony ',
#   'name': 'Adapter',
#   'no': '12349',
#   'pr': 300,
#   'qn': 20},
#  '1010': {'comp': 'buzz', 'name': 'cone', 'no': '12310', 'pr': 30, 'qn': 50},
#  '1011': {'comp': 'fassi',
#   'name': 'buiscuit',
#   'no': '123411',
#   'pr': 50,
#   'qn': 30},
#  '1012': {'comp': 'Maa Plast',
#   'name': 'vegetable basket',
#   'no': '123412',
#   'pr': 100,
#   'qn': 50},
#  '1013': {'comp': 'Danone',
#   'name': 'yogurt',
#   'no': '123413',
#   'pr': 50,
#   'qn': 10},
#  '1014': {'comp': 'Rani herbals',
#   'name': 'Tooth paste',
#   'no': '123414',
#   'pr': 45,
#   'qn': 30},
#  '1015': {'comp': 'bimbo',
#   'name': 'pizza base',
#   'no': '123415',
#   'pr': 100,
#   'qn': 50},
#  '1016': {'comp': 'COca-Cola',
#   'name': 'soft drink',
#   'no': '123416',
#   'pr': 30,
#   'qn': 22},
#  '1017': {'comp': 'johnson pvt ltd',
#   'name': 'soap',
#   'no': '123417',
#   'pr': 10,
#   'qn': 50},
#  '1018': {'comp': 'Lenor',
#   'name': 'ditergent',
#   'no': '123418',
#   'pr': 70,
#   'qn': 10},
#  '1019': {'comp': 'port',
#   'name': 'laundry soap',
#   'no': '123419',
#   'pr': 30,
#   'qn': 10},
#  '1020': {'comp': 'Nestle',
#   'name': 'chocolate',
#   'no': '123420',
#   'pr': 20,
#   'qn': 5},
#  '1021': {'comp': 'lux',
#   'name': 'beauty soap',
#   'no': '123421',
#   'pr': 45,
#   'qn': 5},
#  '1022': {'comp': 'hartleys',
#   'name': 'jam',
#   'no': '123422',
#   'pr': 75,
#   'qn': 4},
#  '1023': {'comp': 'almarai',
#   'name': 'cupcakes',
#   'no': '123423',
#   'pr': 35,
#   'qn': 10},
#  '1024': {'comp': 'cheez whiz',
#   'name': 'cheese',
#   'no': '123424',
#   'pr': 400,
#   'qn': 1},
#  '1025': {'comp': 'velveeta',
#   'name': 'egg',
#   'no': '123425',
#   'pr': 20,
#   'qn': 15},
#  '1026': {'comp': 'fleischmanns yeast',
#   'name': 'yeast',
#   'no': '123426',
#   'pr': 5,
#   'qn': 500},
#  '1027': {'comp': 'branston',
#   'name': 'pickel',
#   'no': '1027',
#   'pr': 300,
#   'qn': 10},
#  '1028': {'comp': 'chicken tonight',
#   'name': 'sause',
#   'no': '123428',
#   'pr': 150,
#   'qn': 2},
#  '1029': {'comp': 'knorr',
#   'name': 'noodles',
#   'no': '123429',
#   'pr': 100,
#   'qn': 25},
#  '1030': {'comp': 'nutella',
#   'name': 'nut butter',
#   'no': '123430',
#   'pr': 400,
#   'qn': 10}}

# %%
prod_id = str(input("Enter product id:"))
name = str(input("Enter name:"))
pr = int(input("Enter price:"))
qn = int(input("Enter quantity:"))
comp = str(input("Enter Manufacturer company:"))
no = str(input("Enter number:"))

record[prod_id] = {'name': name, 'no': no, 'pr': pr, 'qn': qn, 'comp': comp}

js = json.dumps(record)

fd = open("record.json",'w')


fd.write(js)
fd.close()
# Out:
# Enter product id:1022
# Enter name:kisan jam
# Enter price:75
# Enter quantity:4
# Enter Manufacturer company:Kisan
# Enter number:123455

# %%
record
# Out:
# {'1001': {'comp': 'fasai',
#   'name': 'Choco Cake',
#   'no': 12348,
#   'pr': 100,
#   'qn': 34},
#  '1002': {'comp': 'Amul',
#   'name': 'Milk Cake',
#   'no': 12348,
#   'pr': 800,
#   'qn': 100},
#  '1003': {'comp': 'cocacola',
#   'name': 'Drink',
#   'no': 12348,
#   'pr': 85,
#   'qn': 100},
#  '1004': {'comp': 'Amul', 'name': 'Candy', 'no': 12348, 'pr': 5, 'qn': 1000},
#  '1005': {'comp': 'cello', 'name': 'Pen', 'no': 12348, 'pr': 20, 'qn': 100},
#  '1006': {'comp': 'iphone',
#   'name': 'Phone',
#   'no': 12348,
#   'pr': 50000,
#   'qn': 10},
#  '1007': {'comp': 'Sony', 'name': 'Mic', 'no': 12348, 'pr': 1500, 'qn': 0},
#  '1008': {'comp': 'Sony India Pt Ltd',
#   'name': 'Case',
#   'no': 12348,
#   'pr': 599,
#   'qn': 5},
#  '1009': {'comp': 'Sony ',
#   'name': 'Adapter',
#   'no': '12349',
#   'pr': 300,
#   'qn': 20},
#  '1010': {'comp': 'buzz', 'name': 'cone', 'no': '12310', 'pr': 30, 'qn': 50},
#  '1011': {'comp': 'fassi',
#   'name': 'buiscuit',
#   'no': '123411',
#   'pr': 50,
#   'qn': 30},
#  '1012': {'comp': 'Maa Plast',
#   'name': 'vegetable basket',
#   'no': '123412',
#   'pr': 100,
#   'qn': 50},
#  '1013': {'comp': 'Danone',
#   'name': 'yogurt',
#   'no': '123413',
#   'pr': 50,
#   'qn': 10},
#  '1014': {'comp': 'Rani herbals',
#   'name': 'Tooth paste',
#   'no': '123414',
#   'pr': 45,
#   'qn': 30},
#  '1015': {'comp': 'bimbo',
#   'name': 'pizza base',
#   'no': '123415',
#   'pr': 100,
#   'qn': 50},
#  '1016': {'comp': 'COca-Cola',
#   'name': 'soft drink',
#   'no': '123416',
#   'pr': 30,
#   'qn': 22},
#  '1017': {'comp': 'johnson pvt ltd',
#   'name': 'soap',
#   'no': '123417',
#   'pr': 10,
#   'qn': 50},
#  '1018': {'comp': 'Lenor',
#   'name': 'ditergent',
#   'no': '123418',
#   'pr': 70,
#   'qn': 10},
#  '1019': {'comp': 'port',
#   'name': 'laundry soap',
#   'no': '123419',
#   'pr': 30,
#   'qn': 10},
#  '1020': {'comp': 'Nestle',
#   'name': 'chocolate',
#   'no': '123420',
#   'pr': 20,
#   'qn': 5},
#  '1021': {'comp': 'lux',
#   'name': 'beauty soap',
#   'no': '123421',
#   'pr': 45,
#   'qn': 5},
#  '1022': {'comp': 'Kisan',
#   'name': 'kisan jam',
#   'no': '123455',
#   'pr': 75,
#   'qn': 4},
#  '1023': {'comp': 'almarai',
#   'name': 'cupcakes',
#   'no': '123423',
#   'pr': 35,
#   'qn': 10},
#  '1024': {'comp': 'cheez whiz',
#   'name': 'cheese',
#   'no': '123424',
#   'pr': 400,
#   'qn': 1},
#  '1025': {'comp': 'velveeta',
#   'name': 'egg',
#   'no': '123425',
#   'pr': 20,
#   'qn': 15},
#  '1026': {'comp': 'fleischmanns yeast',
#   'name': 'yeast',
#   'no': '123426',
#   'pr': 5,
#   'qn': 500},
#  '1027': {'comp': 'branston',
#   'name': 'pickel',
#   'no': '1027',
#   'pr': 300,
#   'qn': 10},
#  '1028': {'comp': 'chicken tonight',
#   'name': 'sause',
#   'no': '123428',
#   'pr': 150,
#   'qn': 2},
#  '1029': {'comp': 'knorr',
#   'name': 'noodles',
#   'no': '123429',
#   'pr': 100,
#   'qn': 25},
#  '1030': {'comp': 'nutella',
#   'name': 'nut butter',
#   'no': '123430',
#   'pr': 400,
#   'qn': 10}}
